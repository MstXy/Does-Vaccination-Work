# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\hp\Desktop\nyu\senior 1\Information Visualization\Project\Does-Vaccination-Work-main\processed_data\ten_days.csv')
df.info
# Out:
# <bound method DataFrame.info of       CountryName     Date         V1     V2         V3     V4  \
# 0           Aruba  2020010   0.000000   0.00   0.000000    NaN
# 1           Aruba  2020011   0.000000   0.00   0.000000    NaN
# 2           Aruba  2020012   0.000000   0.00   0.000000    NaN
# 3           Aruba  2020020   0.000000   0.00   0.000000    NaN
# 4           Aruba  2020021   0.000000   0.00   0.000000    NaN
# ...           ...      ...        ...    ...        ...    ...
# 19131       World  2022100  98.295455  87.02  94.186047  False
# 19132       World  2022101  98.857143  86.35  93.099415  False
# 19133       World  2022102  98.816568  85.45  92.848485  False
# 19134       World  2022110  99.342105  86.17  96.054422  False
# 19135       World  2022111  99.115044  86.06  95.636364  False
#
#        ConfirmedCases  ConfirmedDeaths MajorityVaccinated  \
# 0                 NaN              NaN                NaN
# 1                 NaN              NaN                NaN
# ...

# %%
country31 = ['Russia', 'China', 'India', 'United Kingdom', 'France', 
                    'Germany', 'Italy', 'Saudi Arabia', 'Iran', 'Egypt', 
                    'South Africa', 'Canada', 'Australia', 'United States', 
                    'Brazil', 'Mexico','Greece','Indonesia','New Zealand',
                    'Argentina','Finland','Turkey','Ukraine','Japan','Spain',
                    'Mali','South Korea','Kazakhstan','Peru','Colombia','World']
df1 = df.loc[df['CountryName'].isin(country31)]
df1 = df1.reset_index()
df1 = df1.drop(columns=['index'])
df1
# Out:
#      CountryName     Date         V1     V2         V3     V4  ConfirmedCases  \
# 0      Argentina  2020010   0.000000   0.00   0.000000    NaN             NaN
# 1      Argentina  2020011   0.000000   0.00   0.000000    NaN             NaN
# 2      Argentina  2020012   0.000000   0.00   0.000000    NaN             0.0
# 3      Argentina  2020020   0.000000   0.00   0.000000    NaN             0.0
# 4      Argentina  2020021   0.000000   0.00   0.000000    NaN             0.0
# ...          ...      ...        ...    ...        ...    ...             ...
# 3219       World  2022100  98.295455  87.02  94.186047  False     619174120.0
# 3220       World  2022101  98.857143  86.35  93.099415  False     624034208.0
# 3221       World  2022102  98.816568  85.45  92.848485  False     627813026.0
# 3222       World  2022110  99.342105  86.17  96.054422  False     631537475.0
# 3223       World  2022111  99.115044  86.06  95.636364  False     635591527.0
#
# ...

# %%
df1.to_csv('ten_days_31.csv',index= False)
