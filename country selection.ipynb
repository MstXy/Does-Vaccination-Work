# %% [markdown]
# Country Selection

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\hp\Desktop\nyu\senior 1\Information Visualization\Project\covid-policy-tracker-master\data\OxCGRT_nat_differentiated_withnotes_2020.csv')
data.head()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_14084/1977862313.py:1: DtypeWarning: Columns (121,122,130) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'C:\Users\hp\Desktop\nyu\senior 1\Information Visualization\Project\covid-policy-tracker-master\data\OxCGRT_nat_differentiated_withnotes_2020.csv')
#   CountryName CountryCode  RegionName  RegionCode Jurisdiction      Date  \
# 0       Aruba         ABW         NaN         NaN    NAT_TOTAL  20200101
# 1       Aruba         ABW         NaN         NaN    NAT_TOTAL  20200102
# 2       Aruba         ABW         NaN         NaN    NAT_TOTAL  20200103
# 3       Aruba         ABW         NaN         NaN    NAT_TOTAL  20200104
# 4       Aruba         ABW         NaN         NaN    NAT_TOTAL  20200105
#
#    C1E_School closing  C1E_Flag  C1NV_School closing  C1NV_Flag  ...  \
# 0                 0.0       NaN                  NaN        NaN  ...
# ...

# %%
data['CountryName'].value_counts()
# Out:
# Aruba       366
# Oman        366
# Malaysia    366
# Namibia     366
# Niger       366
#            ...
# Guinea      366
# Gambia      366
# Greece      366
# Grenada     366
# Zimbabwe    366
# Name: CountryName, Length: 187, dtype: int64

# %%
data['CountryName'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland', 'Chile',
#        'China', "Cote d'Ivoire", 'Cameroon',
#        'Democratic Republic of Congo', 'Congo', 'Colombia', 'Comoros',
#        'Cape Verde', 'Costa Rica', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic',
#        'Algeria', 'Ecuador', 'Egypt', 'Eritrea', 'Spain', 'Estonia',
#        'Ethiopia', 'Finland', 'Fiji', 'France', 'Faeroe Islands', 'Gabon',
#        'United Kingdom', 'Georgia', 'Ghana', 'Guinea', 'Gambia', 'Greece',
# ...

# %%
country = data['CountryName'].unique()

# %%
country = list(country)
country
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'United Arab Emirates',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Switzerland',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Democratic Republic of Congo',
#  'Congo',
#  'Colombia',
#  'Comoros',
#  'Cape Verde',
#  'Costa Rica',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Djibouti',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'Ecuador',
#  'Egypt',
#  'Eritrea',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'Finland',
#  'Fiji',
#  'France',
#  'Faeroe Islands',
#  'Gabon',
#  'United Kingdom',
#  'Georgia',
# ...

# %%
# Test if a country is collected
if 'South Korea' in country:
    print('True')
else:
    print('False')
# Out:
# True

# %% [markdown]
# 16 Country list

# %%
country_16 = ['Russia', 'China', 'India', 'United Kingdom', 'France', 'Germany', 'Italy', 'Saudi Arabia', 'Congo', 'Egypt', 'South Africa', 'Canada', 'Australia', 'United States', 'Brazil', 'Mexico']

# %% [markdown]
# 20 Country list

# %%
country_20 = ['Russia', 'China', 'India', 'United Kingdom', 'France', 'Germany', 'Italy', 'Saudi Arabia', 'Congo', 'Egypt', 'South Africa', 'Canada', 'Australia', 'United States', 'Brazil', 'Mexico','Greenland','Indonesia','New Zealand','Argentina']

# %% [markdown]
# 30 Country list

# %%
country_30 = ['Russia', 'China', 'India', 'United Kingdom', 'France', 'Germany', 'Italy', 'Saudi Arabia', 'Congo', 'Egypt', 'South Africa', 'Canada', 'Australia', 'United States', 'Brazil', 'Mexico','Greenland','Indonesia','New Zealand','Argentina','Finland','Turkey','Ukraine','Japan','Spain','Mali','South Korea','Kazakhstan','Peru','Columbia']
